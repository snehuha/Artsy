# %%
import os
import cv2
import matplotlib.pyplot as plt
print("All set")
# Out:
# All set

# %%
base_path = "../data/images/dataset_updated/training_set"
categories = os.listdir(base_path)
print(categories)
# Out:
# ['drawings', 'engraving', 'iconography', 'painting']

# %%
first_category = categories[0]
category_path = os.path.join(base_path, first_category)

image_name = os.listdir(category_path)[0]
image_path = os.path.join(category_path, image_name)

print(image_path)
# Out:
# ../data/images/dataset_updated/training_set\drawings\01dee7c857692cce250fcc7fba309f3f.jpg

# %%
img = cv2.imread(image_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(643.5), np.float64(474.5), np.float64(-0.5))

# %%
import pickle
with open("../model/image_paths.pkl", "rb") as f:
    paths = pickle.load(f)
print(paths[:3])
# Out:
# ['data\\images\\dataset_updated\\training_set\\drawings\\01dee7c857692cce250fcc7fba309f3f.jpg', 'data\\images\\dataset_updated\\training_set\\drawings\\1007036943.jpg', 'data\\images\\dataset_updated\\training_set\\drawings\\10288_mainfoto_05.jpg']
